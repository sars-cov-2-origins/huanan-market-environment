# %%
import taxoniq

mammals = {}
non_mammals = {}
not_found = set()

f = open('../clustering98_accessions.txt')

for line in f.readlines():
    acc = line.split(">")[1].split()[0]
    name = " ".join(line.split(">")[1].replace(" UNVERIFIED: ", " ").split()[1:3])

    try:
        t = taxoniq.Taxon(scientific_name=name)
        ranks = [(t.rank.name, t.scientific_name) for t in t.ranked_lineage]
        species = ''
        genus = ''
        for rank in ranks:
            if rank[0] == 'species':
                species = rank[1]
            if rank[0] == 'genus':
                genus = rank[1]

        if ('class', 'Mammalia') in ranks:
            mammals[acc] = species
        else:
            non_mammals[acc] = species

    except:
        not_found.add(line.strip())
f.close()

# %%
import gzip
from Bio import SeqIO

genomes = {}
with gzip.open('../mitochondria_dereplicated98.fasta.gz', 'rt') as handle:
    for record in SeqIO.parse(handle, 'fasta'):
        # Process each record as needed
        genomes[record.id] = record.seq

# %%
def mutate_sequence(seq, mutation_rate):
    nucleotides = ['A', 'C', 'G', 'T']
    seq_list = list(seq)
    
    num_mutations = int(len(seq) * mutation_rate)
    
    for _ in range(num_mutations):
        position = random.randint(0, len(seq) - 1)
        # Select a new nucleotide that is different from the current one
        new_nucleotide = random.choice([n for n in nucleotides if n != seq_list[position]])
        seq_list[position] = new_nucleotide
    
    mutated_seq = ''.join(seq_list)
    
    return mutated_seq

# %%
mutate = [0,0.01,0.03,0.05]
iterations = 100
import pandas as pd
import random

for i in range(0, iterations):
    mammal_sample = random.sample(sorted(mammals), 20)
    non_mammal_sample = random.sample(sorted(non_mammals), 40)
    
    for m in mutate:
        f = open("mt_simulated_m" + str(m) + "_"  + str(i) + ".fasta", "w")
        for acc in mammal_sample:
            seq = mutate_sequence(genomes[acc], m)
            f.write(">" + acc + "_" + mammals[acc].replace(" ","_") + "\n")
            f.write(seq + "\n")
        for acc in non_mammal_sample:
            seq = mutate_sequence(genomes[acc], m)
            f.write(">" + acc + "_" + non_mammals[acc].replace(" ","_") + "\n")
            f.write(seq + "\n")
        f.close()

# %%
mammals
# Out:
# {'NC_035621.1': 'Rattus baluensis',
#  'NC_008426.1': 'Erignathus barbatus',
#  'NC_035503.1': 'Neodon sikimensis',
#  'JF681039.1': 'Sotalia guianensis',
#  'NC_020712.1': 'Hippotragus equinus',
#  'NC_053815.1': 'Golunda ellioti',
#  'NC_050031.1': 'Microsciurus sabanillae',
#  'NC_022424.1': 'Lophostoma silvicolum',
#  'NC_020679.1': 'Antilocapra americana',
#  'NC_036319.1': 'Myotis yumanensis',
#  'NC_064150.1': 'Aotus trivirgatus',
#  'MG983792.1': 'Sorex isodon',
#  'KR059226.1': 'Capra aegagrus',
#  'NC_035655.1': 'Cheirogaleus major',
#  'NC_050682.1': 'Callithrix aurita',
#  'NC_006901.1': 'Colobus guereza',
#  'KY425609.1': 'Trachypithecus phayrei',
#  'NC_013068.1': 'Tscherskia triton',
#  'KC516778.1': 'Uropsilus sp.',
#  'NC_007393.1': 'Rousettus aegyptiacus',
#  'JN632673.1': 'Odocoileus virginianus',
#  'NC_020644.1': 'Melogale moschata',
#  'NC_061537.1': 'Balionycteris maculata',
#  'NC_065071.1': 'Hylomyscus aeta',
#  'CM024384.1': 'Pipistrellus kuhlii',
#  'NC_046485.1': 'Hydrictis maculicollis',
#  'KY117566.1': 'Maxomys surifer',
#  'ON023486.1': 'Crocidura sp.',
#  'MT279068.1': 'Papio anubis',
#  'NC_006519.1': 'Pseudocheirus peregrinus',
#  'NC_072557.1': 'Mus minutoides',
#  'MW592432.1': 'Dendrohyrax dorsalis',
#  'OK512927.1': 'Ursus arctos',
#  'NC_065688.1': 'Lonchophylla concava',
#  'NC_008219.1': 'Piliocolobus badius',
#  'NC_015484.1': 'Plecotus auritus',
#  'NC_024604.1': 'Suncus murinus',
#  'NC_009685.1': 'Gulo gulo',
#  'CM044019.1': 'Suncus etruscus',
#  'OQ694762.1': 'Marmota sibirica',
#  'NC_018598.1': 'Uropsilus sp.',
#  'NC_037444.1': 'Eubalaena glacialis',
#  'MN816163.1': 'Chlorocebus aethiops',
#  'NC_034720.1': 'Lepilemur edwardsi',
#  'JN632705.1': 'Tragelaphus scriptus',
#  'NC_035815.1': 'Callosciurus notatus',
#  'NC_068211.1': 'Microtus montanus',
#  'NC_012096.1': 'Capricornis crispus',
#  'NC_053972.1': 'Galerella sanguinea',
#  'MF893970.1': 'Macaca fascicularis',
#  'NC_020656.1': 'Ovis ammon',
#  'NC_034724.1': 'Lepilemur otto',
#  'NC_023950.1': 'Blarinella quadraticauda',
#  'NC_020748.1': 'Tragelaphus angasii',
#  'NC_029346.1': 'Myotis myotis',
#  'NC_064169.1': 'Cebus unicolor',
#  'OM135342.1': 'Eospalax fontanierii',
#  'NC_059325.1': 'Lemur catta',
#  'KM112309.1': 'Microcebus rufus',
#  'NC_020744.1': 'Rusa alfredi',
#  'NC_018535.1': 'Eospalax rothschildi',
#  'MK603869.1': 'Mustela richardsonii',
#  'NC_046900.1': 'Casinycteris campomaanensis',
#  'NC_004563.1': 'Muntiacus muntjak',
#  'NC_056332.1': 'Parascaptor leucura',
#  'NC_022420.1': 'Anoura caudifer',
#  'NC_014864.1': 'Rattus villosissimus',
#  'NC_064181.1': 'Leontocebus fuscicollis',
#  'NC_034722.1': 'Lepilemur randrianasoloi',
#  'NC_066654.1': 'Romerolagus diazi',
#  'NC_050569.1': 'Lepus yarkandensis',
#  'KY117601.1': 'Presbytis melalophos',
#  'MF872233.1': 'Trachypithecus germaini',
#  'MZ353590.1': 'Lophuromys chrysopus',
#  'NC_073527.1': 'Elephantulus rupestris',
#  'NC_006518.1': 'Tarsipes rostratus',
#  'NC_064176.1': 'Saguinus bicolor',
#  'MZ579648.1': 'Ia io',
#  'NC_039419.1': 'Proechimys hoplomyoides',
#  'MN845748.1': 'Hylomyscus walterverheyeni',
#  'AB863014.1': 'Ursus thibetanus',
#  'NC_028321.1': 'Leopardus guigna',
#  'OL677856.1': 'Ochotona thibetana',
#  'MT806046.1': 'Trachypithecus phayrei',
#  'NC_028501.1': 'Bradypus variegatus',
#  'NC_009968.1': 'Helarctos malayanus',
#  'NC_035818.1': 'Sundamys muelleri',
#  'KX819316.1': 'Pteronotus sp.',
#  'NC_009969.1': 'Tremarctos ornatus',
#  'NC_021381.1': 'Naemorhedus goral',
#  'MF143484.1': 'Myotis nigricans',
#  'NC_018053.1': 'Panthera leo',
#  'OX465476.1': 'Chionomys nivalis',
#  'NC_065074.1': 'Hylomyscus kerbispeterhansi',
#  'NC_026063.1': 'Ovis orientalis',
#  'NC_050029.1': 'Hadrosciurus spadiceus',
#  'KU892786.1': 'Lonchothrix emiliae',
#  'NC_022805.1': 'Tursiops australis',
#  'MT381924.1': 'Alticola olchonensis',
#  'LR884195.1': 'Capra hircus',
#  'NC_065086.1': 'Zelotomys hildegardeae',
#  'NC_035800.1': 'Mammut americanum',
#  'NC_072169.1': 'Macrotus waterhousii',
#  'OM329982.1': 'Eospalax smithii',
#  'NC_013751.1': 'Naemorhedus caudatus',
#  'NC_034738.1': 'Lepilemur hollandorum',
#  'NC_001992.1': 'Papio hamadryas',
#  'NC_002078.1': 'Orycteropus afer',
#  'NC_010299.1': 'Daubentonia madagascariensis',
#  'MH974763.1': 'Cercopithecus erythrotis',
#  'NC_027115.1': 'Catopuma temminckii',
#  'MG196296.1': 'Phataginus tricuspis',
#  'NC_023263.1': 'Meriones unguiculatus',
#  'NC_007704.2': 'Cervus elaphus',
#  'OX485834.1': 'Erinaceus europaeus',
#  'NC_020721.1': 'Mazama rufina',
#  'NC_025952.1': 'Mus spretus',
#  'MN122902.1': 'Apodemus flavicollis',
#  'NC_042667.1': 'Gerbilliscus leucogaster',
#  'MT259126.1': 'Hadrosciurus ignitus',
#  'NC_035820.1': 'Trichys fasciculata',
#  'NC_042734.1': 'Blarina brevicauda',
#  'NC_036430.1': 'Muntiacus putaoensis',
#  'KU200225.1': 'Eothenomys inez',
#  'KX755315.1': 'Proechimys guyannensis',
#  'NC_026034.1': 'Myospalax psilurus',
#  'NC_053808.1': 'Dephomys defua',
#  'NC_029477.1': 'Myodes rufocanus',
#  'MW205890.1': 'Spilogale interrupta',
#  'NC_073532.1': 'Galegeeska rufescens',
#  'NC_050024.1': 'Simosciurus stramineus',
#  'NC_033378.1': 'Civettictis civetta',
#  'NC_053816.1': 'Micaelamys namaquensis',
#  'NC_032301.1': 'Stenella longirostris',
#  'NC_046913.1': 'Hypsignathus monstrosus',
#  'NC_020643.1': 'Martes foina',
#  'NC_065402.1': 'Niviventer lotipes',
#  'NC_004919.1': 'Procavia capensis',
#  'NC_021478.1': 'Rhizomys pruinosus',
#  'OQ694745.1': 'Marmota caligata',
#  'NC_056368.1': 'Herpestes ichneumon',
#  'NC_045060.1': 'Rucervus duvaucelii',
#  'NC_010300.1': 'Eulemur mongoz',
#  'NC_036419.1': 'Rhinolophus yunnanensis',
#  'NC_051518.1': 'Stenocephalemys albocaudata',
#  'KY117602.1': 'Presbytis melalophos',
#  'MN845749.1': 'Hylomyscus walterverheyeni',
#  'MT381930.1': 'Lemmus trimucronatus',
#  'JN632683.1': 'Pecari tajacu',
#  'NC_019802.1': 'Theropithecus gelada',
#  'NC_019583.1': 'Trachypithecus johnii',
#  'KM112327.1': 'Cheirogaleus medius',
#  'LS992657.1': 'Capra hircus',
#  'KX258452.1': 'Panthera spelaea',
#  'MW592439.1': 'Procavia capensis',
#  'NC_020694.1': 'Cephalophus silvicultor',
#  'NC_046920.1': 'Myonycteris leptodon',
#  'NC_053810.1': 'Hybomys trivirgatus',
#  'NC_016427.1': 'Myodes regulus',
#  'NC_050027.1': 'Hadrosciurus igniventris',
#  'KU892755.1': 'Euryzygomatomys spinosus',
#  'NC_008419.1': 'Neophoca cinerea',
#  'NC_062616.1': 'Canis simensis',
#  'NC_023780.1': 'Ratufa bicolor',
#  'NC_014867.1': 'Rattus fuscipes',
#  'MT410898.1': 'Micromys minutus',
#  'NC_035601.1': 'Microcebus mamiratra',
#  'NC_027935.1': 'Vulpes ferrilata',
#  'MZ457418.1': 'Cryptotis tropicalis',
#  'NC_026442.1': 'Dremomys rufigenis',
#  'NC_020009.2': 'Papio papio',
#  'NC_049871.1': 'Myotis septentrionalis',
#  'NC_052688.1': 'Soriculus nigrescens',
#  'NC_015243.1': 'Microtus fortis',
#  'NC_056379.1': 'Antechinus flavipes',
#  'OL677845.1': 'Ochotona thibetana',
#  'MT381937.1': 'Lasiopodomys gregalis',
#  'NC_013840.1': 'Cervus elaphus',
#  'NC_056111.1': 'Myotis ricketti',
#  'NC_037437.1': 'Macaca sinica',
#  'NC_020620.1': 'Tragelaphus spekii',
#  'NC_002009.1': 'Artibeus jamaicensis',
#  'NC_001644.1': 'Pan paniscus',
#  'NC_027424.1': 'Macropus giganteus',
#  'NC_048991.1': 'Dremomys everetti',
#  'MW209721.1': 'Niviventer cremoriventer',
#  'KM893421.1': 'Sotalia fluviatilis',
#  'NC_008414.3': 'Rusa unicolor',
#  'KY464172.1': 'Sundamys muelleri',
#  'NC_035630.1': 'Microcebus simmonsi',
#  'CM027365.1': 'Potos flavus',
#  'NC_056326.1': 'Trachypithecus phayrei',
#  'NC_027692.1': 'Stylodipus telum',
#  'KP257597.1': 'Rhinolophus sinicus',
#  'KR816507.1': 'Hystrix brachyura',
#  'KY996501.1': 'Osphranter rufus',
#  'NC_070363.1': 'Ochotona argentata',
#  'MN038168.1': 'Chodsigoa smithii',
#  'NC_039923.1': 'Cervus elaphus',
#  'ON165343.1': 'Eothenomys proditor',
#  'NC_012761.1': 'Galago senegalensis',
#  'MT381932.1': 'Microtus socialis',
#  'ON165321.1': 'Eothenomys olitor',
#  'NC_053980.1': 'Atilax paludinosus',
#  'NC_052873.1': 'Ochotona coreana',
#  'NC_056324.1': 'Trachypithecus geei',
#  'NC_014042.1': 'Hylobates agilis',
#  'NC_058019.1': 'Oryx dammah',
#  'ON165310.1': 'Eothenomys eleusis',
#  'KX768725.1': 'Proechimys quadruplicatus',
#  'MT381928.1': 'Chionomys gud',
#  'AM905041.1': 'Hylomys suillus',
#  'MW193729.1': 'Niviventer fulvescens',
#  'FJ207522.1': 'Ammotragus lervia',
#  'NC_058016.1': 'Zalophus japonicus',
#  'NC_033356.1': 'Neotoma fuscipes',
#  'NC_020734.1': 'Pelea capreolus',
#  'NC_019580.1': 'Trachypithecus germaini',
#  'KU892765.1': 'Trinomys yonenagae',
#  'NC_065675.1': 'Anoura cultrata',
#  'NC_020667.1': 'Simias concolor',
#  'NC_065685.1': 'Micronycteris hirsuta',
#  'NC_024860.1': 'Sus celebensis',
#  'NC_020728.1': 'Neotragus moschatus',
#  'NC_001779.1': 'Rhinoceros unicornis',
#  'MT381933.1': 'Microtus daghestanicus',
#  'NC_026095.1': 'Indri indri',
#  'MZ594566.1': 'Scaptochirus moschatus',
#  'KU892759.1': 'Phyllomys mantiqueirensis',
#  'NC_073528.1': 'Macroscelides flavicaudatus',
#  'NC_026992.1': 'Sus barbatus',
#  'NC_064189.1': 'Alouatta discolor',
#  'JX101653.1': 'Pseudois nayaur',
#  'NC_037527.1': 'Bradypus tridactylus',
#  'KU940257.1': 'Laonastes aenigmamus',
#  'NC_049041.1': 'Rattus sp.',
#  'NC_042694.1': 'Blarina hylophaga',
#  'KX529109.1': 'Anomalurus beecrofti',
#  'OM329957.1': 'Eospalax rufescens',
#  'NC_022423.1': 'Desmodus rotundus',
#  'NC_036314.1': 'Myotis keaysi',
#  'NC_030342.1': 'Mus famulus',
#  'NC_027604.1': 'Macaca leonina',
#  'NC_026723.1': 'Urocyon cinereoargenteus',
#  'NC_028562.1': 'Chaetophractus villosus',
#  'MZ457524.1': 'Tylonycteris fulvida',
#  'NC_062277.1': 'Lutra lutra',
#  'NC_042217.1': 'Mesoplodon mirus',
#  'NC_053966.1': 'Crossarchus platycephalus',
#  'NC_053976.1': 'Viverra zibetha',
#  'KU892763.1': 'Trinomys paratus',
#  'NC_023210.1': 'Mustela kathiah',
#  'NC_066831.1': 'Leptonycteris yerbabuenae',
#  'NC_034734.1': 'Lepilemur sahamalazensis',
#  'MT240890.1': 'Syntheosciurus brochus',
#  'NC_024592.1': 'Cricetulus kamensis',
#  'NC_020647.1': 'Nasua nasua',
#  'NC_039545.1': 'Proechimys goeldii',
#  'OQ439776.1': 'Ursus arctos',
#  'MW205876.1': 'Spilogale gracilis',
#  'KY117538.1': 'Callosciurus erythraeus',
#  'NC_008156.1': 'Galemys pyrenaicus',
#  'NC_023960.1': 'Niviventer confucianus',
#  'NC_053257.1': 'Talpa aquitania',
#  'NC_020619.1': 'Tragelaphus imberbis',
#  'NC_035598.1': 'Peromyscus pectoralis',
#  'ON165293.1': 'Cricetulus kamensis',
#  'ON643072.1': 'Elephantulus brachyrhynchus',
#  'LS992648.1': 'Capra hircus',
#  'NC_035597.1': 'Reithrodontomys mexicanus',
#  'NC_011124.1': 'Ailurus fulgens',
#  'MN460851.1': 'Glis glis',
#  'NC_053802.1': 'Arvicanthis rufinus',
#  'OK323273.1': 'Chionomys nivalis',
#  'OQ694750.1': 'Marmota flaviventris',
#  'NC_003322.1': 'Vombatus ursinus',
#  'OQ439773.1': 'Ursus arctos',
#  'NC_053814.1': 'Thallomys paedulcus',
#  'NC_065076.1': 'Mastomys erythroleucus',
#  'OP006054.1': 'Ochotona dauurica',
#  'KR537890.1': 'Crocidura beatus',
#  'NC_011579.1': 'Martes zibellina',
#  'NC_012684.1': 'Dicerorhinus sumatrensis',
#  'NC_023542.1': 'Beatragus hunteri',
#  'MK397764.1': 'Neomonachus tropicalis',
#  'AY960979.1': 'Bradypus variegatus',
#  'NC_005971.1': 'Bos indicus',
#  'NC_065684.1': 'Lonchophylla robusta',
#  'KM112316.1': 'Microcebus rufus',
#  'NC_005825.1': 'Thylamys elegans',
#  'NC_022421.1': 'Brachyphylla cavernarum',
#  'NC_035656.1': 'Mirza coquereli',
#  'MT259125.1': 'Hadrosciurus ignitus',
#  'NC_028536.1': 'Rhinolophus rex',
#  'NC_036732.1': 'Maxomys surifer',
#  'NC_020759.1': 'Loxodonta cyclotis',
#  'NC_020326.1': 'Rhinolophus ferrumequinum',
#  'NC_028305.1': 'Prionailurus viverrinus',
#  'NC_029762.1': 'Condylura cristata',
#  'KT818538.1': 'Choloepus hoffmanni',
#  'LC536646.1': 'Macaca fascicularis',
#  'NC_064132.1': 'Brachylagus idahoensis',
#  'KY117540.1': 'Callosciurus finlaysonii',
#  'OM329038.1': 'Cebus albifrons',
#  'NC_021955.1': 'Loris lydekkerianus',
#  'NC_025270.1': 'Mus cookii',
#  'NC_020700.1': 'Dama dama',
#  'NC_038163.1': 'Zenkerella insignis',
#  'NC_035595.1': 'Podomys floridanus',
#  'KU892775.1': 'Kannabateomys amblyonyx',
#  'NC_006929.1': 'Balaenoptera borealis',
#  'NC_017599.1': 'Apodemus chevrieri',
#  'NC_020614.1': 'Boselaphus tragocamelus',
#  'KU892769.1': 'Mesocapromys melanurus',
#  'NC_039669.1': 'Eudorcas thomsonii',
#  'KU892784.1': 'Toromys grandis',
#  'ON165375.1': 'Neodon shergylaensis',
#  'CM024385.1': 'Molossus molossus',
#  'NC_050995.1': 'Lasionycteris noctivagans',
#  'NC_046949.1': 'Cavia aperea',
#  'KM112331.1': 'Cheirogaleus crossleyi',
#  'NC_028565.1': 'Dasypus hybridus',
#  'MW257214.1': 'Urva javanica',
#  'NC_065401.1': 'Eothenomys eleusis',
#  'NC_035816.1': 'Callosciurus prevostii',
#  'OP006099.1': 'Ochotona sikimaria',
#  'CM050754.1': 'Eptesicus fuscus',
#  'KU892756.1': 'Phyllomys blainvillii',
#  'ON165295.1': 'Microtus maximowiczii',
#  'MT381941.1': 'Phenacomys intermedius',
#  'NC_069019.1': 'Sicista betulina',
#  'OP006025.1': 'Ochotona cansus',
#  'KF776494.1': 'Panthera leo',
#  'NC_062361.1': 'Hippotragus niger',
#  'OQ199699.1': 'Macaca mulatta',
#  'NC_057519.1': 'Didelphis pernigra',
#  'NC_005434.1': 'Rhinolophus pumilus',
#  'NC_020758.1': 'Acomys cahirinus',
#  'HE978360.1': 'Graphiurus kelleni',
#  'NC_020682.1': 'Blastocerus dichotomus',
#  'MF872235.1': 'Trachypithecus barbei',
#  'NC_020737.1': 'Potamochoerus porcus',
#  'NC_041303.1': 'Kogia sima',
#  'NC_034313.1': 'Dicrostonyx groenlandicus',
#  'NC_045900.1': 'Suricata suricatta',
#  'NC_028625.1': 'Castor fiber',
#  'NC_018603.1': 'Kobus leche',
#  'NC_008137.1': 'Phalanger vestitus',
#  'NC_020637.1': 'Mustela sibirica',
#  'MH345727.1': 'Procapra picticaudata',
#  'NC_041638.1': 'Myotis frater',
#  'NC_049152.1': 'Otaria byronia',
#  'NC_006522.1': 'Notoryctes typhlops',
#  'NC_012694.1': 'Moschus berezovskii',
#  'MW387162.1': 'Microtus richardsoni',
#  'NC_024172.1': 'Chrysocyon brachyurus',
#  'MT892666.1': 'Didelphis virginiana',
#  'NC_049120.1': 'Heimyscus fumosus',
#  'NC_023958.1': 'Vulpes corsac',
#  'NC_035606.1': 'Mirza zaza',
#  'NC_057104.1': 'Bandicota bengalensis',
#  'NC_041486.1': 'Elephantulus edwardii',
#  'KY996500.1': 'Wallabia bicolor',
#  'NC_005358.1': 'Ochotona princeps',
#  'NC_013753.1': 'Moschus moschiferus',
#  'NC_018061.1': 'Pygathrix nigripes',
#  'NC_005436.1': 'Pipistrellus abramus',
#  'NC_020617.1': 'Syncerus caffer',
#  'KU682696.1': 'Chlorocebus pygerythrus',
#  'NC_029191.1': 'Pipistrellus coromandra',
#  'NC_001325.1': 'Phoca vitulina',
#  'NC_038176.1': 'Microtus arvalis',
#  'JX101652.1': 'Pseudois nayaur',
#  'LC548013.1': 'Hylobates albibarbis',
#  'NC_044972.1': 'Monachus monachus',
#  'NC_020630.1': 'Oreamnos americanus',
#  'NC_035613.1': 'Peromyscus megalops',
#  'NC_042737.1': 'Megatherium americanum',
#  'MN845681.1': 'Hylomyscus denniae',
#  'NC_002746.1': 'Isoodon macrourus',
#  'NC_008434.1': 'Vulpes vulpes',
#  'NC_002083.1': 'Pongo abelii',
#  'NC_011822.1': 'Lama guanicoe',
#  'LN873134.1': 'Tragulus javanicus',
#  'KX688205.1': 'Proechimys longicaudatus',
#  'KU892752.1': 'Carterodon sulcidens',
#  'KY464179.1': 'Leopoldamys edwardsi',
#  'NC_019582.1': 'Trachypithecus vetulus',
#  'NC_037180.1': 'Peromyscus leucopus',
#  'NC_012775.1': 'Saimiri sciureus',
#  'NC_018057.1': 'Rhinopithecus brelichi',
#  'NC_013558.1': 'Vicugna vicugna',
#  'NC_020703.1': 'Gazella bennettii',
#  'NC_061570.1': 'Hipposideros larvatus',
#  'NC_045044.1': 'Rousettus amplexicaudatus',
#  'NC_036035.1': 'Ondatra zibethicus',
#  'NC_053753.1': 'Phocoenoides dalli',
#  'NC_036434.1': 'Manis culionensis',
#  'NC_024568.1': 'Genetta servalina',
#  'MZ457417.1': 'Cryptotis merriami',
#  'OM329987.1': 'Eospalax fontanierii',
#  'OM501056.1': 'Microtus richardsoni',
#  'NC_035612.1': 'Habromys ixtlani',
#  'NC_037466.1': 'Macaca mulatta',
#  'NC_039591.1': 'Paradoxurus hermaphroditus',
#  'NC_027418.1': 'Eothenomys melanogaster',
#  'NC_046902.1': 'Cynopterus sphinx',
#  'GU570660.1': 'Rattus leucopus',
#  'MF374796.1': 'Sorex caecutiens',
#  'NC_036330.1': 'Tadarida teniotis',
#  'MF438265.1': 'Sorex mirabilis',
#  'KU899140.1': 'Presbytis femoralis',
#  'NC_023963.1': 'Cercopithecus diana',
#  'MW193740.1': 'Niviventer andersoni',
#  'NC_008066.1': 'Chlorocebus sabaeus',
#  'NC_006520.1': 'Macrotis lagotis',
#  'NC_020715.1': 'Kobus ellipsiprymnus',
#  'ON165286.1': 'Lagurus lagurus',
#  'NC_039921.1': 'Peromyscus maniculatus',
#  'NC_020736.1': 'Philantomba monticola',
#  'NC_046929.1': 'Rousettus obliviosus',
#  'MT381940.1': 'Myodes centralis',
#  'NC_036369.1': 'Otocyon megalotis',
#  'KU892787.1': 'Mesomys hispidus',
#  'NC_046928.1': 'Rousettus madagascariensis',
#  'NC_013563.1': 'Proedromys liangshanensis',
#  'NC_034718.1': 'Lepilemur fleuretae',
#  'NC_069653.1': 'Trichosurus caninus',
#  'NC_020646.1': 'Taxidea taxus',
#  'NC_007631.1': 'Sminthopsis crassicaudata',
#  'OP524493.1': 'Peromyscus californicus',
#  'NC_036331.1': 'Tadarida latouchei',
#  'NC_049122.1': 'Apodemus sylvaticus',
#  'NC_028323.1': 'Otocolobus manul',
#  'NC_042754.1': 'Parocnus serus',
#  'MH464793.1': 'Paradoxurus jerdoni',
#  'NC_006524.1': 'Potorous tridactylus',
#  'ON260904.1': 'Musonycteris harrisoni',
#  'NC_070063.1': 'Vulpes chama',
#  'NC_039551.1': 'Proechimys trinitatis',
#  'NC_020714.1': 'Hyemoschus aquaticus',
#  'MH056211.1': 'Rhynchocyon udzungwensis',
#  'MT936555.1': 'Cercopithecus mona',
#  'NC_008428.1': 'Phoca fasciata',
#  'NC_025902.1': 'Lepus hainanus',
#  'NC_034277.1': 'Chlorocebus djamdjamensis',
#  'NC_020793.1': 'Oryx beisa',
#  'MW205843.1': 'Spilogale gracilis',
#  'MN845707.1': 'Hylomyscus parvus',
#  'KM112310.1': 'Microcebus rufus',
#  'NC_064202.1': 'Plecturocebus caligatus',
#  'KU892760.1': 'Phyllomys pattoni',
#  'KY117563.1': 'Maxomys rajah',
#  'NC_064171.1': 'Leontocebus nigricollis',
#  'KX768703.1': 'Proechimys gardneri',
#  'NC_043879.1': 'Porcula salvania',
#  'NC_026542.1': 'Pteropus vampyrus',
#  'MH464791.1': 'Hemigalus derbyanus',
#  'NC_028150.1': 'Uropsilus sp.',
#  'NC_028577.1': 'Zaedyus pichiy',
#  'NC_065749.1': 'Chionomys roberti',
#  'NC_021435.1': 'Ziphius cavirostris',
#  'NC_009747.1': 'Chlorocebus pygerythrus',
#  'ON528113.1': 'Peromyscus aztecus',
#  'OQ675160.1': 'Spermophilus taurensis',
#  'MW193735.1': 'Niviventer tenaster',
#  'NC_034731.1': 'Lepilemur seali',
#  'NC_009510.1': 'Ammotragus lervia',
#  'NC_002619.1': 'Pteropus scapulatus',
#  'NC_002764.1': 'Macaca sylvanus',
#  'NC_001321.1': 'Balaenoptera physalus',
#  'NC_039723.1': 'Oligoryzomys stramineus',
#  'NC_030070.1': 'Lariscus insignis',
#  'NC_006364.1': 'Zaglossus bruijni',
#  'MN845728.1': 'Hylomyscus stella',
#  'KT023074.1': 'Sorex cylindricauda',
#  'MW193732.1': 'Niviventer eha',
#  'KY996509.1': 'Petrogale xanthopus',
#  'NC_024628.1': 'Callimico goeldii',
#  'MN326850.1': 'Microtus subterraneus',
#  'MT381922.1': 'Alticola lemminus',
#  'KT824773.1': 'Mesechinus hughi',
#  'NC_035593.1': 'Peromyscus attwateri',
#  'ON675568.1': 'Galegeeska rufescens',
#  'ON165339.1': 'Neodon linzhiensis',
#  'NC_046910.1': 'Epomops buettikoferi',
#  'NC_004029.2': 'Odobenus rosmarus',
#  'JN800721.1': 'Galeopterus variegatus',
#  'NC_005315.1': 'Nannospalax ehrenbergi',
#  'NC_033912.1': 'Castor canadensis',
#  'NC_065676.1': 'Anoura geoffroyi',
#  'NC_034330.1': 'Mustela itatsi',
#  'NC_001913.1': 'Oryctolagus cuniculus',
#  'NC_028568.1': 'Dasypus sabanicola',
#  'NC_028555.1': 'Bradypus torquatus',
#  'KM892823.1': 'Myodes glareolus',
#  'MT259114.1': 'Microsciurus flaviventer',
#  'NC_009492.1': 'Ailuropoda melanoleuca',
#  'ON165337.1': 'Volemys musseri',
#  'MZ556326.1': 'Crocidura nicobarica',
#  'MT381935.1': 'Microtus guentheri',
#  'KU892762.1': 'Trinomys iheringi',
#  'NC_057557.1': 'Microtus chrotorrhinus',
#  'NC_057092.1': 'Eudiscopus denticulus',
#  'KX688199.1': 'Proechimys longicaudatus',
#  'NC_002521.1': 'Tupaia belangeri',
#  'NC_020675.1': 'Aepyceros melampus',
#  'NC_039548.1': 'Proechimys pattoni',
#  'NC_009331.1': 'Ursus thibetanus',
#  'NC_053960.1': 'Eupleres goudotii',
#  'NC_042243.1': 'Marmota flaviventris',
#  'NC_002391.1': 'Talpa europaea',
#  'ON165345.1': 'Alexandromys oeconomus',
#  'NC_020628.1': 'Hemitragus jemlahicus',
#  'MF872232.1': 'Trachypithecus delacouri',
#  'NC_026443.1': 'Hylopetes phayrei',
#  'NC_036421.1': 'Saccopteryx leptura',
#  'NC_024942.1': 'Mustela nigripes',
#  'NC_037878.1': 'Leontopithecus chrysopygus',
#  'NC_049034.1': 'Sundasciurus hippurus',
#  'MN816351.1': 'Rousettus aegyptiacus',
#  'ON528119.1': 'Reithrodontomys mexicanus',
#  'NC_065683.1': 'Choeroniscus minor',
#  'KX688192.1': 'Proechimys cuvieri',
#  'NC_032373.1': 'Tamias dorsalis',
#  'NC_060307.1': 'Bubalus quarlesi',
#  'NC_065077.1': 'Mastomys kollmannspergeri',
#  'NC_039103.1': 'Proechimys semispinosus',
#  'NC_034306.1': 'Rhinolophus thomasi',
#  'MZ570954.1': 'Sicista betulina',
#  'NC_013993.1': 'Homo sp.',
#  'MT259081.1': 'Guerlinguetus aestuans',
#  'NC_023089.1': 'Petaurista hainana',
#  'NC_019799.1': 'Aotus lemurinus',
#  'KU892753.1': 'Clyomys laticeps',
#  'NC_027932.1': 'Micromys minutus',
#  'NC_018116.1': 'Aotus nancymaae',
#  'NC_018780.1': 'Equus zebra',
#  'NC_041100.1': 'Muntiacus feae',
#  'NC_071768.1': 'Spermophilus alashanicus',
#  'KU892758.1': 'Phyllomys lundi',
#  'NC_020732.1': 'Oryx leucoryx',
#  'ON165346.1': 'Neodon medogensis',
#  'NC_036315.1': 'Myotis ruber',
#  'NC_002612.1': 'Pteropus dasymallus',
#  'NC_019585.1': 'Apodemus latronum',
#  'NC_057516.1': 'Didelphis aurita',
#  'NC_056341.1': 'Cercopithecus neglectus',
#  'NC_035557.1': 'Microcebus myoxinus',
#  'NC_011125.1': 'Meles meles',
#  'NC_020697.1': 'Hexaprotodon liberiensis',
#  'NC_016189.1': 'Prionailurus bengalensis',
#  'NC_039099.1': 'Proechimys cuvieri',
#  'NC_034227.1': 'Myotis bechsteinii',
#  'NC_020010.2': 'Papio ursinus',
#  'NC_008447.1': 'Lagostrophus fasciatus',
#  'NC_064168.1': 'Saimiri ustus',
#  'NC_049116.1': 'Otomys irroratus',
#  'NC_046927.1': 'Rousettus leschenaultii',
#  'KM893423.1': 'Sotalia fluviatilis',
#  'NC_021944.1': 'Cercopithecus albogularis',
#  'NC_053812.1': 'Dasymys incomtus',
#  'NC_019581.1': 'Trachypithecus shortridgei',
#  'NC_035604.1': 'Cheirogaleus crossleyi',
#  'NC_038162.1': 'Idiurus macrotis',
#  'NC_024051.1': 'Tarsius lariang',
#  'MZ457415.1': 'Cryptotis lacertosus',
#  'NC_064157.1': 'Chiropotes chiropotes',
#  'NC_002808.1': 'Echinosorex gymnura',
#  'NC_071871.1': 'Habromys lophurus',
#  'NC_026088.1': 'Megaladapis edwardsi',
#  'OP006011.1': 'Ochotona cansus',
#  'NC_021959.1': 'Prolemur simus',
#  'MT408179.1': 'Stenocephalemys sokolovi',
#  'NC_020695.1': 'Cephalophus spadix',
#  'NC_023541.1': 'Sus cebifrons',
#  'MW257206.1': 'Ursus arctos',
#  'NC_053965.1': 'Cynictis penicillata',
#  'MZ570935.1': 'Sicista betulina',
#  'KU697359.1': 'Solenodon paradoxus',
#  'NC_063622.1': 'Chimarrogale leander',
#  'NC_031210.1': 'Callospermophilus lateralis',
#  'NC_005280.1': 'Phocoena phocoena',
#  'NC_027684.1': 'Meriones meridianus',
#  'KU892785.1': 'Isothrix sinnamariensis',
#  'MH464789.1': 'Herpestes semitorquatus',
#  'NC_065085.1': 'Praomys morio',
#  'ON528114.1': 'Peromyscus crinitus',
#  'NC_023922.1': 'Petaurista alborufus',
#  'NC_046934.1': 'Rousettus lanosus',
#  'KM112325.1': 'Cheirogaleus crossleyi',
#  'KU940255.1': 'Laonastes aenigmamus',
#  'NC_007936.1': 'Cricetulus griseus',
#  'MW193728.1': 'Niviventer gladiusmaculus',
#  'NC_034808.1': 'Sorex roboratus',
#  'NC_039409.1': 'Proechimys echinothrix',
#  'NC_020618.1': 'Taurotragus derbianus',
#  'OP210313.1': 'Tupaia belangeri',
#  'NC_028300.1': 'Catopuma badia',
#  'KM893422.1': 'Sotalia fluviatilis',
#  'MT671405.1': 'Muntiacus muntjak',
#  'NC_014855.1': 'Rattus leucopus',
#  'NC_036320.1': 'Myotis auriculus',
#  'KX755322.1': 'Proechimys roberti',
#  'NC_034730.1': 'Lepilemur aeeclis',
#  'MZ457413.1': 'Cryptotis gracilis',
#  'OM328964.1': 'Cebus unicolor',
#  'NC_022429.1': 'Vampyrum spectrum',
#  'NC_008427.1': 'Cystophora cristata',
#  'NC_046917.1': 'Megaloglossus woermanni',
#  'ON165373.1': 'Ellobius tancrei',
#  'KM893428.1': 'Inia geoffrensis',
#  'NC_065375.1': 'Mazama temama',
#  'LC225390.1': 'Macaca fascicularis',
#  'KY070168.1': 'Tamias ruficaudus',
#  'NC_012920.1': 'Homo sapiens',
#  'NC_010641.1': 'Panthera pardus',
#  'NC_034795.1': 'Trachypithecus poliocephalus',
#  'NC_033353.1': 'Pteronotus personatus',
#  'OP006103.1': 'Ochotona cansus',
#  'NC_025277.1': 'Tamias sibiricus',
#  'MG586969.1': 'Megaderma lyra',
#  'NC_018367.1': 'Marmota himalayana',
#  'NC_053975.1': 'Poecilogale albinucha',
#  'JF681040.1': 'Sotalia fluviatilis',
#  'NC_027579.1': 'Sicista concolor',
#  'NC_004920.1': 'Chrysochloris asiatica',
#  'NC_060655.1': 'Equus hemionus',
#  'NC_000889.1': 'Hippopotamus amphibius',
#  'NC_039670.1': 'Neotoma magister',
#  'NC_049033.1': 'Sundasciurus robinsoni',
#  'JN632593.1': 'Alcelaphus buselaphus',
#  'NC_016871.1': 'Artibeus lituratus',
#  'NC_035561.1': 'Microcebus sambiranensis',
#  'KM112322.1': 'Cheirogaleus major',
#  'MT157215.1': 'Sundasciurus lowii',
#  'NC_005275.1': 'Platanista minor',
#  'KU892788.1': 'Mesomys stimulax',
#  'NC_020633.1': 'Rupicapra rupicapra',
#  'NC_032371.1': 'Tamias rufus',
#  'NC_012387.1': 'Mus musculus',
#  'NC_053968.1': 'Genetta genetta',
#  'NC_065160.1': 'Tupaia nicobarica',
#  'NC_026090.1': 'Palaeopropithecus ingens',
#  'NC_010497.1': 'Spilogale putorius',
#  'KP708706.1': 'Spermophilus dauricus',
#  'NC_037174.1': 'Sorex sinalis',
#  'AJ428945.1': 'Procavia capensis',
#  'OQ694760.1': 'Marmota olympus',
#  'NC_056331.1': 'Cricetulus sokolovi',
#  'NC_053750.1': 'Phocoena spinipinnis',
#  'NC_004069.1': 'Muntiacus reevesi',
#  'NC_042604.1': 'Moschus leucogaster',
#  'MF143495.1': 'Myotis nigricans',
#  'NC_008417.1': 'Arctocephalus pusillus',
#  'NC_036312.1': 'Myotis dominicensis',
#  'NC_042596.1': 'Conepatus chinga',
#  'NC_034236.1': 'Delphinapterus leucas',
#  'KU579289.1': 'Petaurista elegans',
#  'NC_026915.1': 'Myospalax aspalax',
#  'NC_053269.1': 'Rhinolophus affinis',
#  'NC_026875.1': 'Tamiops swinhoei',
#  'NC_020752.1': 'Tragelaphus strepsiceros',
#  'NC_004577.1': 'Muntiacus crinifrons',
#  'NC_061569.1': 'Kerivoula minuta',
#  'NC_014858.1': 'Rattus lutreolus',
#  'NC_037859.1': 'Sorex gracillimus',
#  'ON165307.1': 'Neodon forresti',
#  'NC_025271.1': 'Capreolus pygargus',
#  'OK539643.1': 'Babyrousa babyrussa',
#  'NC_034348.1': 'Indopacetus pacificus',
#  'NC_012103.1': 'Pecari tajacu',
#  'NC_038174.1': 'Anomalurus pusillus',
#  'MT093212.1': 'Mastomys natalensis',
#  'KY792714.1': 'Moschus berezovskii',
#  'NC_035812.1': 'Sundasciurus brookei',
#  'NC_026976.1': 'Macaca nemestrina',
#  'NC_027499.1': 'Dipus sagitta',
#  'ON165287.1': 'Myodes rutilus',
#  'NC_018753.1': 'Nomascus gabriellae',
#  'NC_042753.1': 'Nothrotheriops shastensis',
#  'NC_006299.1': 'Monodelphis domestica',
#  'NC_050983.1': 'Lepus oiostolus',
#  'OK163841.1': 'Cynopterus brachyotis',
#  'MT806055.1': 'Trachypithecus phayrei',
#  'NC_025283.1': 'Lasiopodomys mandarinus',
#  'NC_046923.1': 'Nanonycteris veldkampii',
#  'NC_057634.1': 'Dasycercus cristicauda',
#  'MT259587.1': 'Cynopterus sphinx',
#  'LS992597.1': 'Capra hircus',
#  'NC_028309.1': 'Felis nigripes',
#  'MT806031.1': 'Trachypithecus cristatus',
#  'MK359635.1': 'Rhombomys opimus',
#  'NC_022422.1': 'Carollia perspicillata',
#  'NC_035560.1': 'Microcebus tavaratra',
#  'NC_065083.1': 'Praomys jacksoni',
#  'KY581660.1': 'Chaerephon plicatus',
#  'MT755630.1': 'Macaca leucogenys',
#  'NC_050383.1': 'Elaphodus cephalophus',
#  'NC_036323.1': 'Myotis thysanodes',
#  'MH109998.1': 'Camelus dromedarius',
#  'KP694301.1': 'Apodemus draco',
#  'NC_036729.1': 'Sundamys annandalei',
#  'KX755303.1': 'Proechimys echinothrix',
#  'NC_053751.1': 'Phocoena sinus',
#  'MT663338.1': 'Dasyurus spartacus',
#  'NC_053967.1': 'Ichneumia albicauda',
#  'KX755324.1': 'Proechimys simonsi',
#  'NC_032375.1': 'Tamias striatus',
#  'NC_027828.1': 'Mungotictis decemlineata',
#  'NC_014453.1': 'Lepilemur hubbardorum',
#  'KM112330.1': 'Cheirogaleus medius',
#  'MZ196220.1': 'Hipposideros pendleburyi',
#  'MT381929.1': 'Lasiopodomys raddei',
#  'NC_050264.1': 'Muscardinus avellanarius',
#  'NC_045217.1': 'Murexia melanurus',
#  'NC_011304.1': 'Rhinolophus formosae',
#  'NC_026131.1': 'Episoriculus caudatus',
#  'ON165370.1': 'Eothenomys colurnus',
#  'NC_051516.1': 'Stenocephalemys sokolovi',
#  'OQ694752.1': 'Marmota baibacina',
#  'NC_035629.1': 'Microcebus berthae',
#  'NC_070048.1': 'Crocidura leucodon',
#  'NC_035572.1': 'Sigmodon hispidus',
#  'NC_020008.2': 'Papio kindae',
#  'NC_020746.1': 'Saiga tatarica',
#  'NC_014047.1': 'Symphalangus syndactylus',
#  'NC_057635.1': 'Macroderma gigas',
#  'NC_064194.1': 'Ateles geoffroyi',
#  'NC_057558.1': 'Microtus thomasi',
#  'MT936556.1': 'Cercopithecus mitis',
#  'NC_054246.1': 'Vormela peregusna',
#  'NC_053807.1': 'Stochomys longicaudatus',
#  'NC_020707.1': 'Gazella gazella',
#  'KU892771.1': 'Plagiodontia aedium',
#  'KX891745.1': 'Viverricula indica',
#  'NC_028576.1': 'Tolypeutes tricinctus',
#  'NC_037941.1': 'Mylodon darwinii',
#  'NC_050265.1': 'Lagenorhynchus acutus',
#  'NC_047188.1': 'Peromyscus eremicus',
#  'NC_001646.1': 'Pongo pygmaeus',
#  'NC_028559.1': 'Cabassous unicinctus',
#  'KU892766.1': 'Capromys pilorides',
#  'NC_006924.1': 'Choloepus didactylus',
#  'NC_064187.1': 'Alouatta macconnelli',
#  'NC_061914.1': 'Holochilus sciureus',
#  'NC_016428.1': 'Apodemus agrarius',
#  'NC_041639.1': 'Ectophylla alba',
#  'NC_030330.1': 'Eothenomys miletus',
#  'NC_067757.1': 'Canis aureus',
#  'KY996504.1': 'Notamacropus parma',
#  'MZ353592.1': 'Lophuromys menageshae',
#  'KX688189.1': 'Proechimys semispinosus',
#  'NC_028566.1': 'Dasypus kappleri',
#  'NC_011116.1': 'Arctodus simus',
#  'NC_057520.1': 'Lutreolina crassicaudata',
#  'MH345726.1': 'Ochotona thibetana',
#  'MT381943.1': 'Microtus miurus',
#  'NC_021940.1': 'Avahi laniger',
#  'NC_006900.1': 'Trachypithecus obscurus',
#  'NC_042943.1': 'Myotragus balearicus',
#  'NC_044489.1': 'Miniopterus fuliginosus',
#  'NC_006914.1': 'Mus musculus',
#  'NC_006928.1': 'Balaenoptera brydei',
#  'NC_049119.1': 'Maxomys whiteheadi',
#  'NC_022694.1': 'Myotis macrodactylus',
#  'CM047939.1': 'Corynorhinus townsendii',
#  'KX688196.1': 'Proechimys cuvieri',
#  'ON165377.1': 'Volemys millicens',
#  'NC_035813.1': 'Sundasciurus lowii',
#  'NC_009748.1': 'Chlorocebus tantalus',
#  'NC_002080.2': 'Erinaceus europaeus',
#  'NC_020750.1': 'Tragelaphus oryx',
#  'NC_064198.1': 'Cheracebus torquatus',
#  'KP708705.1': 'Dremomys pyrrhomerus',
#  'NC_001892.1': 'Glis glis',
#  'ON165317.1': 'Alexandromys limnophilus',
#  'NC_050993.1': 'Tupaia minor',
#  'MT381927.1': 'Blanfordimys juldaschi',
#  'NC_021957.1': 'Nomascus leucogenys',
#  'KU521385.1': 'Murina huttoni',
#  'NC_068809.1': 'Neotoma albigula',
#  'KM893424.1': 'Sotalia guianensis',
#  'NC_001643.1': 'Pan troglodytes',
#  'NC_036321.1': 'Myotis leibii',
#  'NC_028312.1': 'Prionailurus planiceps',
#  'NC_034646.1': 'Dicrostonyx torquatus',
#  'ON643071.1': 'Elephantulus brachyrhynchus',
#  'KJ944209.1': 'Avahi laniger',
#  'NC_058275.1': 'Tachyoryctes macrocephalus',
#  'NC_020674.1': 'Addax nasomaculatus',
#  'NC_028554.1': 'Bradypus pygmaeus',
#  'CM029269.1': 'Phacochoerus africanus',
#  'MF509825.1': 'Phataginus tetradactyla',
#  'NC_020661.1': 'Octodon degus',
#  'NC_021956.1': 'Mandrillus sphinx',
#  'OM329961.1': 'Eospalax fontanierii',
#  'NC_025268.1': 'Mus caroli',
#  'NC_069637.1': 'Hystrix indica',
#  'ON165388.1': 'Alexandromys oeconomus',
#  'NC_027945.1': 'Microtus ochrogaster',
#  'KM112317.1': 'Microcebus rufus',
#  'NC_050028.1': 'Hadrosciurus pyrrhinus',
#  'NC_023838.1': 'Tapirus indicus',
#  'NC_049121.1': 'Chiropodomys gliroides',
#  'NC_028427.1': 'Lycaon pictus',
#  'NC_024052.1': 'Tarsius dentatus',
#  'MT663337.1': 'Caloprymnus campestris',
#  'KX964606.1': 'Erinaceus amurensis',
#  'ON528115.1': 'Peromyscus megalops',
#  'OM330000.1': 'Eospalax fontanierii',
#  'NC_060697.1': 'Myotis aurascens',
#  'NC_013445.1': 'Cuon alpinus',
#  'KX768704.1': 'Proechimys gardneri',
#  'KX755310.1': 'Proechimys guyannensis',
#  'FJ785425.1': 'Saimiri sciureus',
#  'KJ434961.1': 'Otolemur crassicaudatus',
#  'NC_053799.1': 'Lemniscomys rosalia',
#  'NC_036508.1': 'Macaca radiata',
#  'NC_066722.1': 'Bassaricyon gabbii',
#  'MN122828.1': 'Arvicola amphibius',
#  'NC_023543.1': 'Damaliscus lunatus',
#  'NC_036326.1': 'Myotis volans',
#  'NC_064175.1': 'Mico argentatus',
#  'NC_056333.1': 'Episoriculus leucops',
#  'NC_037778.1': 'Echimys saturnus',
#  'NC_019626.1': 'Neotetracus sinensis',
#  'NC_036325.1': 'Myotis horsfieldii',
#  'MN935778.1': 'Muscardinus avellanarius',
#  'NC_035819.1': 'Leopoldamys sabanus',
#  'OQ673175.1': 'Crocidura wuchihensis',
#  'MN845696.1': 'Hylomyscus pamfi',
#  'NC_005269.1': 'Caperea marginata',
#  'NC_011638.1': 'Rattus tanezumi',
#  'NC_008424.1': 'Leptonychotes weddellii',
#  'NC_018358.1': 'Elaphurus davidianus',
#  'NC_061978.1': 'Rhinolophus huananus',
#  'NC_012771.1': 'Eulemur macaco',
#  'ON165342.1': 'Eothenomys custos',
#  'NC_056988.1': 'Maxomys ochraceiventer',
#  'MT259086.1': 'Guerlinguetus aestuans',
#  'NC_027243.1': 'Crocidura palawanensis',
#  'NC_042196.1': 'Sorex minutissimus',
#  'LR632920.1': 'Marmota monax',
#  'NC_041144.1': 'Uropsilus andersoni',
#  'NC_020757.1': 'Nannospalax golani',
#  'ON165322.1': 'Eothenomys eva',
#  'NC_003039.1': 'Trichosurus vulpecula',
#  'LC552838.1': 'Mus musculus',
#  'CM055130.1': 'Mirounga angustirostris',
#  'MN845686.1': 'Hylomyscus heinrichorum',
#  'MT663340.1': 'Microperoryctes murina',
#  'NC_063946.1': 'Nesolagus timminsi',
#  'NC_005276.1': 'Inia geoffrensis',
#  'NC_020681.1': 'Axis porcinus',
#  'ON165285.1': 'Eothenomys miletus',
#  'NC_003427.1': 'Ursus arctos',
#  'NC_016470.1': 'Puma concolor',
#  'NC_003041.1': 'Microtus kikuchii',
#  'NC_006853.1': 'Bos taurus',
#  'NC_035600.1': 'Microcebus danfossi',
#  'NC_049117.1': 'Mus baoulei',
#  'NC_019590.1': 'Orcaella brevirostris',
#  'JX312694.1': 'Trinomys dimidiatus',
#  'NC_040138.1': 'Neodon fuscus',
#  'NC_001808.1': 'Ceratotherium simum',
#  'NC_056388.1': 'Dinaromys bogdanovi',
#  'NC_046901.1': 'Casinycteris ophiodon',
#  'NC_053957.1': 'Galidictis fasciata',
#  'NC_021954.1': 'Lophocebus aterrimus',
#  'KM892835.1': 'Myodes glareolus',
#  'KP708708.1': 'Sciurotamias davidianus',
#  'LR862378.1': 'Pipistrellus pipistrellus',
#  'NC_009629.2': 'Camelus ferus',
#  'NC_020669.1': 'Hyaena hyaena',
#  'MN816304.1': 'Cynopterus brachyotis',
#  'KX891751.1': 'Viverricula indica',
#  'NC_014044.1': 'Bison bonasus',
#  'NC_059784.1': 'Spermophilus citellus',
#  'MN695893.1': 'Geocapromys ingrahami',
#  'MZ131562.1': 'Praomys daltoni',
#  'NC_007179.1': 'Cervus nippon',
#  'HM068590.1': 'Pan troglodytes',
#  'MZ457410.1': 'Cryptotis mexicanus',
#  'KJ530560.1': 'Mus cervicolor',
#  'NC_073531.1': 'Rhynchocyon stuhlmanni',
#  'NC_030071.1': 'Callosciurus adamsi',
#  'MT279069.1': 'Papio cynocephalus',
#  'MN845628.1': 'Hylomyscus aeta',
#  'NC_037136.1': 'Macrotus californicus',
#  'NC_014456.1': 'Lynx rufus',
#  'NC_057515.1': 'Didelphis albiventris',
#  'MZ457411.1': 'Cryptotis goldmani',
#  'NC_031330.1': 'Uropsilus gracilis',
#  'NC_046924.1': 'Nyctimene cephalotes',
#  'NC_002503.2': 'Physeter catodon',
#  'NC_050026.1': 'Glaucomys volans',
#  'NC_012766.1': 'Eulemur fulvus',
#  'NC_064200.1': 'Plecturocebus bernhardi',
#  'OQ199571.1': 'Macaca assamensis',
#  'NC_023347.1': 'Rattus niobe',
#  'NC_024041.1': 'Lepus townsendii',
#  'NC_042752.1': 'Acratocnus ye',
#  'JX946204.2': 'Papio ursinus',
#  'NC_037888.1': 'Cricetus cricetus',
#  'NC_023244.1': 'Uropsilus soricipes',
#  'NC_037132.1': 'Chrotopterus auritus',
#  'MN845715.1': 'Hylomyscus simus',
#  'NC_013700.1': 'Nyctereutes procyonoides',
#  'KY070177.1': 'Tamias ruficaudus',
#  'NC_061372.1': 'Phascolosorex doriae',
#  'NC_025516.1': 'Mustela erminea',
#  'MG196310.1': 'Phataginus tricuspis',
#  'KX755313.1': 'Proechimys guyannensis',
#  'NC_020742.1': 'Redunca fulvorufula',
#  'CM050047.1': 'Cynocephalus volans',
#  'NC_028557.1': 'Cabassous chacoensis',
#  'NC_012141.1': 'Martes flavigula',
#  'NC_037134.1': 'Hsunycteris thomasi',
#  'MN845739.1': 'Hylomyscus denniae',
#  'MW205885.1': 'Spilogale angustifrons',
#  'NC_007441.1': 'Pantholops hodgsonii',
#  'MN845717.1': 'Hylomyscus simus',
#  'KY117592.1': 'Macaca nigra',
#  'MW193734.1': 'Niviventer fulvescens',
#  'NC_028575.1': 'Tolypeutes matacus',
#  'KX755301.1': 'Proechimys echinothrix',
#  'NC_063561.1': 'Arctocephalus australis',
#  'NC_035564.1': 'Microcebus jollyae',
#  'MZ353589.1': 'Lophuromys simensis',
#  'NC_005828.1': 'Caenolestes fuliginosus',
#  'NC_053956.1': 'Salanoia concolor',
#  'NC_024053.1': 'Tarsius wallacei',
#  'MK747249.1': 'Murina shuipuensis',
#  'NC_035559.1': 'Microcebus bongolavensis',
#  'MT259080.1': 'Guerlinguetus aestuans',
#  'NC_005268.1': 'Balaena mysticetus',
#  'NC_019612.1': 'Pteromys volans',
#  'NC_021119.1': 'Murina ussuriensis',
#  'NC_012374.1': 'Rattus rattus',
#  'MN056567.1': 'Hipposideros larvatus',
#  'NC_030174.1': 'Arctotherium sp.',
#  'NC_001640.1': 'Equus caballus',
#  'NC_068695.1': 'Tupaia glis',
#  'ON400078.1': 'Trichosurus vulpecula',
#  'NC_028572.1': 'Myrmecophaga tridactyla',
#  'NC_061568.1': 'Hipposideros cervinus',
#  'NC_026098.1': 'Eulemur rubriventer',
#  'NC_016008.1': 'Manis pentadactyla',
#  'NC_020615.1': 'Bubalus depressicornis',
#  'NC_035607.1': 'Phaner electromontis',
#  'NC_008093.1': 'Canis latrans',
#  'NC_034735.1': 'Lepilemur tymerlachsoni',
#  'NC_025746.1': 'Akodon montensis',
#  'NC_003426.1': 'Ursus americanus',
#  'NC_060500.1': 'Niviventer andersoni',
#  'NC_005829.1': 'Rhyncholestes raphanurus',
#  'NC_053971.1': 'Chrotogale owstoni',
#  'MT259088.1': 'Guerlinguetus aestuans',
#  'MT259084.1': 'Guerlinguetus aestuans',
#  'LS992629.1': 'Capra hircus',
#  'KY117573.1': 'Niviventer cremoriventer',
#  'MZ457416.1': 'Cryptotis oreoryctes',
#  'KX755305.1': 'Proechimys guyannensis',
#  'NC_015828.1': 'Myotis formosus',
#  'NC_071788.1': 'Lontra canadensis',
#  'NC_020717.1': 'Madoqua kirkii',
#  'NC_014861.1': 'Rattus tunneyi',
#  'NC_026465.1': 'Cynopterus brachyotis',
#  'NC_036724.1': 'Bunomys penitus',
#  'KJ184173.1': 'Rupicapra pyrenaica',
#  'ON165352.1': 'Neodon clarkei',
#  'NC_016422.1': 'Oryx gazella',
#  'KX768716.1': 'Proechimys kulinae',
#  'NC_020688.1': 'Cephalophus jentinki',
#  'OP554562.1': 'Aonyx cinereus',
#  'NC_027963.1': 'Sorex araneus',
#  'NC_020631.1': 'Ovibos moschatus',
#  'NC_036433.1': 'Manis crassicaudata',
#  'NC_025308.1': 'Myotis brandtii',
#  'MT936557.1': 'Cercopithecus mona',
#  'NC_025777.1': 'Scapanulus oweni',
#  'NC_008415.3': 'Callorhinus ursinus',
#  'NC_008418.1': 'Phocarctos hookeri',
#  'NC_035599.1': 'Isthmomys pirrensis',
#  'NC_023368.1': 'Pteronotus parnellii',
#  'MZ457419.1': 'Cryptotis parvus',
#  'NC_036018.1': 'Mastomys coucha',
#  'KM112319.1': 'Cheirogaleus medius',
#  'NC_008429.1': 'Phoca groenlandica',
#  'OM328894.1': 'Cebus unicolor',
#  'NC_020632.1': 'Pseudois nayaur',
#  'NC_007596.2': 'Mammuthus primigenius',
#  'MK903499.1': 'Megatherium americanum',
#  'NC_024819.1': 'Dama mesopotamica',
#  'NC_039100.1': 'Proechimys brevicauda',
#  'NC_038171.1': 'Anomalurus beecrofti',
#  'MZ353591.1': 'Lophuromys melanonyx',
#  'KU892783.1': 'Pattonomys semivillosus',
#  'NC_020792.1': 'Tympanoctomys barrerae',
#  ...}
